# %% [markdown]
# Graph creation.

# %%
pip install pandas matplotlib seaborn

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
file_path = "./EEG_Data_With_Predicted_Disease.csv"
data = pd.read_csv(file_path)

# Check the dataset
print(data.head())

# Plot 1: Distribution of Diagnosed Diseases
plt.figure(figsize=(10, 6))
sns.countplot(data=data, x="Predicted_Disease", order=data["Predicted_Disease"].value_counts().index)
plt.title("Distribution of Diagnosed Diseases", fontsize=16)
plt.xlabel("Disease", fontsize=12)
plt.ylabel("Count", fontsize=12)
plt.xticks(rotation=45)
plt.show()

# Plot 2: Relationship between Mood and Disease
plt.figure(figsize=(12, 8))
sns.boxplot(data=data, x="Predicted_Disease", y="Predicted_Mood", palette="Set2")
plt.title("Mood Levels Across Diagnosed Diseases", fontsize=16)
plt.xlabel("Disease", fontsize=12)
plt.ylabel("Mood Level", fontsize=12)
plt.xticks(rotation=45)
plt.show()

# Plot 3: Correlation Heatmap of Features
plt.figure(figsize=(10, 8))
correlation = data[["x", "y", "z", "Magnitude", "Row_Mean", "Predicted_Mood"]].corr()
sns.heatmap(correlation, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Feature Correlation Heatmap", fontsize=16)
plt.show()

# Plot 4: Pairplot for Selected Features
sns.pairplot(data=data, vars=["x", "y", "z", "Magnitude", "Row_Mean"], hue="Predicted_Disease", palette="Set1")
plt.suptitle("Pairplot of EEG Signals by Disease", y=1.02, fontsize=16)
plt.show()

# Plot 5: Feature Importance (if available)
# Example assumes we have a trained model and feature importances
# Uncomment and use if feature importances are computed

# import numpy as np
# feature_importances = model.feature_importances_  # Replace with actual model's feature importance
# feature_names = ["x", "y", "z", "Magnitude", "Row_Mean", "Predicted_Mood"]

# plt.figure(figsize=(8, 6))
# sns.barplot(x=feature_importances, y=feature_names, palette="viridis")
# plt.title("Feature Importance", fontsize=16)
# plt.xlabel("Importance Score", fontsize=12)
# plt.ylabel("Feature", fontsize=12)
# plt.show()
# Out:
#               x             y             z     Magnitude      Row_Mean  Mood  \
# 0 -3.219647e-17 -3.108624e-17  4.884981e-17 -1.909584e-16  2.220446e-18     2
# 1  1.915135e-17  1.776357e-17  2.442491e-17 -2.176037e-16 -1.013079e-17     0
# 2 -2.109424e-17 -3.219647e-17 -8.437695e-17  3.863576e-16 -1.221245e-17     1
# 3  2.747802e-17 -2.886580e-17 -8.881784e-18 -8.382184e-16 -2.914335e-18     2
# 4  1.332268e-17  2.636780e-17  3.330669e-17 -7.938095e-17 -1.776357e-17     2
#
#    Predicted_Mood  Disease Predicted_Disease
# 0               1        0          Epilepsy
# 1               0        3       Parkinson's
# 2               0        1          Epilepsy
# 3               3        0       Alzheimer's
# 4               0        0       Parkinson's
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_4224\3941693980.py:23: FutureWarning:
#
# ...
