# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import to_categorical
import os

# Step 1: Load the Summary Dataset
summary_file_path = rf"C:\Users\ASUS\OneDrive\Desktop\Brain Disease\BrainDisease_EEG_Data_Summary.csv"
data = pd.read_csv(summary_file_path)

# Step 2: Add a Synthetic "Mood" Column for Demonstration
# This is for training. Replace with real labels if available.
possible_moods = ["Happy", "Sad", "Neutral", "Angry"]
np.random.seed(42)  # For reproducibility
data["Mood"] = np.random.choice(possible_moods, size=len(data))

# Step 3: Preprocess the Data
# Encode the "Mood" column to integers
label_encoder = LabelEncoder()
data["Mood"] = label_encoder.fit_transform(data["Mood"])

# Separate features and labels
features = data[["x", "y", "z", "Magnitude", "Row_Mean"]].values
labels = data["Mood"].values

# Standardize the feature values
scaler = StandardScaler()
features = scaler.fit_transform(features)

# One-hot encode the labels
labels = to_categorical(labels)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.2, random_state=42)

# Step 4: Build the Neural Network Model
model = Sequential([
    Dense(64, input_dim=features.shape[1], activation='relu'),
    Dense(32, activation='relu'),
    Dense(labels.shape[1], activation='softmax')  # Output layer with softmax
])

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Step 5: Train the Model
model.fit(X_train, y_train, epochs=50, batch_size=16, validation_split=0.2, verbose=1)

# Step 6: Predict Moods for All Data
predictions = model.predict(features)
predicted_moods = np.argmax(predictions, axis=1)
data["Predicted_Mood"] = label_encoder.inverse_transform(predicted_moods)

# Step 7: Save the Updated Dataset
output_file_path = "./EEG_Data_With_Predicted_Mood.csv"
data.to_csv(output_file_path, index=False)

print(f"Updated dataset with predicted moods saved: {output_file_path}")
# Out:
# Epoch 1/50
# c:\Users\ASUS\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step - accuracy: 0.2429 - loss: 1.4057 - val_accuracy: 0.2000 - val_loss: 1.4113
# Epoch 2/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.3627 - loss: 1.3580 - val_accuracy: 0.2000 - val_loss: 1.4057
# Epoch 3/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.3507 - loss: 1.3454 - val_accuracy: 0.2000 - val_loss: 1.4046
# Epoch 4/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.3602 - loss: 1.3133 - val_accuracy: 0.2000 - val_loss: 1.4021
# Epoch 5/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.4549 - loss: 1.2830 - val_accuracy: 0.2000 - val_loss: 1.4007
# Epoch 6/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.4146 - loss: 1.2887 - val_accuracy: 0.2000 - val_loss: 1.4058
# Epoch 7/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5642 - loss: 1.2380 - val_accuracy: 0.2000 - val_loss: 1.4109
# Epoch 8/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4637 - loss: 1.2680 - val_accuracy: 0.2500 - val_loss: 1.4134
# Epoch 9/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5373 - loss: 1.2239 - val_accuracy: 0.2500 - val_loss: 1.4157
# Epoch 10/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5165 - loss: 1.2142 - val_accuracy: 0.2000 - val_loss: 1.4200
# Epoch 11/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5174 - loss: 1.2254 - val_accuracy: 0.2000 - val_loss: 1.4237
# Epoch 12/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5411 - loss: 1.2098 - val_accuracy: 0.2000 - val_loss: 1.4265
# Epoch 13/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5592 - loss: 1.1967 - val_accuracy: 0.2000 - val_loss: 1.4328
# Epoch 14/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5545 - loss: 1.1898 - val_accuracy: 0.2000 - val_loss: 1.4359
# Epoch 15/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6439 - loss: 1.1649 - val_accuracy: 0.2000 - val_loss: 1.4389
# Epoch 16/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5578 - loss: 1.1953 - val_accuracy: 0.2000 - val_loss: 1.4403
# Epoch 17/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6238 - loss: 1.1482 - val_accuracy: 0.2000 - val_loss: 1.4441
# Epoch 18/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5856 - loss: 1.1544 - val_accuracy: 0.2000 - val_loss: 1.4452
# Epoch 19/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6194 - loss: 1.1459 - val_accuracy: 0.2000 - val_loss: 1.4471
# Epoch 20/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5786 - loss: 1.1516 - val_accuracy: 0.2000 - val_loss: 1.4522
# Epoch 21/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5882 - loss: 1.1391 - val_accuracy: 0.2000 - val_loss: 1.4550
# Epoch 22/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5882 - loss: 1.1239 - val_accuracy: 0.2000 - val_loss: 1.4555
# Epoch 23/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6125 - loss: 1.1031 - val_accuracy: 0.2000 - val_loss: 1.4589
# Epoch 24/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5377 - loss: 1.1259 - val_accuracy: 0.2000 - val_loss: 1.4585
# Epoch 25/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6635 - loss: 1.0708 - val_accuracy: 0.2000 - val_loss: 1.4627
# Epoch 26/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6054 - loss: 1.1073 - val_accuracy: 0.2000 - val_loss: 1.4681
# Epoch 27/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5655 - loss: 1.0940 - val_accuracy: 0.2000 - val_loss: 1.4709
# Epoch 28/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5583 - loss: 1.1080 - val_accuracy: 0.2000 - val_loss: 1.4716
# Epoch 29/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6479 - loss: 1.0415 - val_accuracy: 0.2000 - val_loss: 1.4699
# Epoch 30/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6497 - loss: 1.0316 - val_accuracy: 0.2500 - val_loss: 1.4764
# Epoch 31/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5868 - loss: 1.0766 - val_accuracy: 0.2500 - val_loss: 1.4751
# Epoch 32/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6016 - loss: 1.0502 - val_accuracy: 0.2500 - val_loss: 1.4751
# Epoch 33/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5755 - loss: 1.0561 - val_accuracy: 0.2500 - val_loss: 1.4768
# Epoch 34/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5988 - loss: 1.0515 - val_accuracy: 0.2500 - val_loss: 1.4795
# Epoch 35/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6066 - loss: 1.0308 - val_accuracy: 0.2500 - val_loss: 1.4819
# Epoch 36/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6457 - loss: 1.0059 - val_accuracy: 0.2500 - val_loss: 1.4843
# Epoch 37/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6498 - loss: 1.0308 - val_accuracy: 0.2500 - val_loss: 1.4842
# Epoch 38/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6831 - loss: 0.9682 - val_accuracy: 0.2500 - val_loss: 1.4887
# Epoch 39/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6794 - loss: 0.9952 - val_accuracy: 0.2500 - val_loss: 1.4884
# Epoch 40/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6418 - loss: 0.9954 - val_accuracy: 0.2500 - val_loss: 1.4947
# Epoch 41/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7177 - loss: 0.9976 - val_accuracy: 0.2500 - val_loss: 1.5008
# Epoch 42/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7333 - loss: 0.9466 - val_accuracy: 0.2500 - val_loss: 1.5042
# Epoch 43/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6951 - loss: 0.9530 - val_accuracy: 0.2500 - val_loss: 1.5093
# Epoch 44/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7672 - loss: 0.8994 - val_accuracy: 0.2500 - val_loss: 1.5090
# Epoch 45/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6837 - loss: 0.9583 - val_accuracy: 0.2500 - val_loss: 1.5094
# Epoch 46/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6969 - loss: 0.9483 - val_accuracy: 0.2500 - val_loss: 1.5115
# Epoch 47/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7065 - loss: 0.8937 - val_accuracy: 0.2500 - val_loss: 1.5113
# Epoch 48/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7323 - loss: 0.8665 - val_accuracy: 0.2500 - val_loss: 1.5151
# Epoch 49/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7437 - loss: 0.8844 - val_accuracy: 0.2500 - val_loss: 1.5189
# Epoch 50/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6733 - loss: 0.9585 - val_accuracy: 0.2500 - val_loss: 1.5235
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Updated dataset with predicted moods saved: ./EEG_Data_With_Predicted_Mood.csv
